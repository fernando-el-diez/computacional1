# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %%
# Lee un archivo de texto con la función Pandas "read_csv", con elementos separados por mas de 
# un espacio, brincándose 4 renglones del inicio (encabezados)
df0 = pd.read_csv('sargento_201117.csv', skiprows=1, sep=',')
# "Shift + Enter"

# %%
# Lee los primeros 5 renglones del archivo
df0.head(5)
# "Shift+Enter"
# Out:
#    #                Fecha     Pres    Temp  WaterLevel
# 0  1  10/26/2017 13:00:00  105.612  24.448      -0.150
# 1  2  10/26/2017 13:15:00  105.513  24.351      -0.160
# 2  3  10/26/2017 13:30:00  105.433  24.351      -0.168
# 3  4  10/26/2017 13:45:00  105.385  24.351      -0.173
# 4  5  10/26/2017 14:00:00  105.321  24.351      -0.179

# %%
df = pd.DataFrame(df0)

# %%
# Ver los tipos de datos que Pandas ha reconocido al leer
df.dtypes
# Out:
# #               int64
# Fecha          object
# Pres          float64
# Temp          float64
# WaterLevel    float64
# dtype: object

# %%
df.head()
# Out:
#    #                Fecha     Pres    Temp  WaterLevel
# 0  1  10/26/2017 13:00:00  105.612  24.448      -0.150
# 1  2  10/26/2017 13:15:00  105.513  24.351      -0.160
# 2  3  10/26/2017 13:30:00  105.433  24.351      -0.168
# 3  4  10/26/2017 13:45:00  105.385  24.351      -0.173
# 4  5  10/26/2017 14:00:00  105.321  24.351      -0.179

# %%
df.dtypes
# Out:
# #               int64
# Fecha          object
# Pres          float64
# Temp          float64
# WaterLevel    float64
# dtype: object

# %%
df.head()
# Out:
#    #                Fecha     Pres    Temp  WaterLevel
# 0  1  10/26/2017 13:00:00  105.612  24.448      -0.150
# 1  2  10/26/2017 13:15:00  105.513  24.351      -0.160
# 2  3  10/26/2017 13:30:00  105.433  24.351      -0.168
# 3  4  10/26/2017 13:45:00  105.385  24.351      -0.173
# 4  5  10/26/2017 14:00:00  105.321  24.351      -0.179

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df['Ndate'] = pd.to_datetime(df['Fecha'], format='%m/%d/%Y %H:%M:%S')
df['month'] = df['Ndate'].dt.month
df.head()
# Out:
#    #                Fecha     Pres    Temp  WaterLevel               Ndate  \
# 0  1  10/26/2017 13:00:00  105.612  24.448      -0.150 2017-10-26 13:00:00
# 1  2  10/26/2017 13:15:00  105.513  24.351      -0.160 2017-10-26 13:15:00
# 2  3  10/26/2017 13:30:00  105.433  24.351      -0.168 2017-10-26 13:30:00
# 3  4  10/26/2017 13:45:00  105.385  24.351      -0.173 2017-10-26 13:45:00
# 4  5  10/26/2017 14:00:00  105.321  24.351      -0.179 2017-10-26 14:00:00
#
#    month
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10

# %%
df.dtypes
# Out:
# #                      int64
# Fecha                 object
# Pres                 float64
# Temp                 float64
# WaterLevel           float64
# Ndate         datetime64[ns]
# month                  int64
# dtype: object

# %%
# graficar Boxplots por mes
# Biblioteca Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="Pres", data=df)
plt.show()

# %%
# graficar Boxplots por mes
# Biblioteca Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="Temp", data=df)
plt.show()

# %%
# graficar Boxplots por mes
# Biblioteca Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="WaterLevel", data=df)
plt.show()

# %%
#grafica de la temperatura-nivel del agua
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("Temp", "WaterLevel", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
# Gráfica de la rapidez de los vientos (m/s) 
plt.figure(); df.WaterLevel.plot(); plt.legend(loc='best')
plt.title("Nivel del mar")
plt.grid(True)
plt.show()

# %%
# Gráfica de la rapidez de los vientos (m/s) 
plt.figure(); df.Temp.plot(); plt.legend(loc='best')
plt.title("Temperatura del agua")
plt.grid(True)
plt.show()

# %%
df1 = df[['Temp','WaterLevel']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("temperatura-nivel del agua")
plt.grid(True)
plt.show()

# %%
#grafica de nivel de mar-salinidad
sns.set(style="darkgrid", color_codes=True)
dfjuntos=pd.concat([df, df1], axis=1, join_axes=[dfsani.index])
g=sns.jointplot("Salinity", "WaterLevel", data=dfjuntos,kind="reg", color="c")
plt.show(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6f31a2d14dec> in <module>()
#       1 #grafica de nivel de mar-salinidad
#       2 sns.set(style="darkgrid", color_codes=True)
# ----> 3 dfjuntos=pd.concat([df, df1], axis=1, join_axes=[dfsani.index])
#       4 g=sns.jointplot("Salinity", "WaterLevel", data=dfjuntos,kind="reg", color="c")
#       5 plt.show(g)
#
# NameError: name 'dfsani' is not defined
